# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/dhs_children_combined.csv")

df.head()
# Out:
#   country  age_months sex  weight_kg  height_cm   haz   waz   whz  \
# 0   India        12.0   F       11.1       90.0  5.65  1.50 -1.39
# 1   India        25.0   F       14.5      102.7  4.61  1.53 -1.16
# 2   India        39.0   M       12.7      109.7  2.98 -1.31 -4.32
# 3   India        57.0   M       26.2      109.4  0.13  2.72  3.93
# 4   India        11.0   M       13.3       76.6  0.51  3.04  3.50
#
#   stunting_status underweight_status  ... iycf_applicable  \
# 0          normal             normal  ...            True
# 1          normal             normal  ...           False
# 2          normal             normal  ...           False
# 3          normal             normal  ...           False
# 4          normal             normal  ...            True
#
#    grains_roots_tubers  legumes_nuts  dairy  flesh_foods  eggs  \
# 0                  1.0           0.0    1.0          0.0   1.0
# 1                  NaN           NaN    NaN          NaN   NaN
# ...

# %%
df.shape
# Out:
# (213328, 24)

# %%
df.columns.tolist()
# Out:
# ['country',
#  'age_months',
#  'sex',
#  'weight_kg',
#  'height_cm',
#  'haz',
#  'waz',
#  'whz',
#  'stunting_status',
#  'underweight_status',
#  'wasting_status',
#  'wealth_index',
#  'mother_education',
#  'currently_breastfeeding',
#  'iycf_applicable',
#  'grains_roots_tubers',
#  'legumes_nuts',
#  'dairy',
#  'flesh_foods',
#  'eggs',
#  'vitamin_a_fruits_veg',
#  'other_fruits_veg',
#  'dietary_diversity_score',
#  'min_dietary_diversity_met']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 213328 entries, 0 to 213327
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   country                    213328 non-null  str
#  1   age_months                 213328 non-null  float64
#  2   sex                        213328 non-null  str
#  3   weight_kg                  213328 non-null  float64
#  4   height_cm                  213328 non-null  float64
#  5   haz                        213328 non-null  float64
#  6   waz                        213328 non-null  float64
#  7   whz                        213328 non-null  float64
#  8   stunting_status            213328 non-null  str
#  9   underweight_status         213328 non-null  str
#  10  wasting_status             213328 non-null  str
#  11  wealth_index               213328 non-null  int64
#  12  mother_education           213328 non-null  int64
# ...

# %%
df.describe()
# Out:
#           age_months      weight_kg      height_cm            haz  \
# count  213328.000000  213328.000000  213328.000000  213328.000000
# mean       30.095393      10.921011      84.437356      -1.367992
# std        17.209823       3.316099      13.866700       1.719720
# min         0.000000       1.700000      45.000000      -6.000000
# 25%        15.000000       8.600000      74.500000      -2.440000
# 50%        30.000000      11.000000      86.000000      -1.470000
# 75%        45.000000      13.200000      95.100000      -0.430000
# max        59.000000      29.800000     120.000000       6.000000
#
#                  waz            whz   wealth_index  mother_education  \
# count  213328.000000  213328.000000  213328.000000     213328.000000
# mean       -1.334716      -0.778739       2.665970          1.563597
# std         1.233409       1.492363       1.379011          0.974277
# min        -5.970000      -5.000000       1.000000          0.000000
# ...
