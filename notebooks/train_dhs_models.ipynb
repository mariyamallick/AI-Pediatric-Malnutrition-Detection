# %%
# DHS Model Training

This notebook contains the workflow for training pediatric malnutrition prediction models using the DHS dataset.
# Out:
#   Cell In[1], line 3
#     This notebook contains the workflow for training pediatric malnutrition prediction models using the DHS dataset.
#          ^
# SyntaxError: invalid syntax
